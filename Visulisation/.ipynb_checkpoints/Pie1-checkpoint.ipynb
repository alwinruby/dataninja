# %%
import numpy as np 
import pandas as pd
# %matplotlib inline

print('numpy, pandas have been imported.')
# Out:
# numpy, pandas have been imported.

# %%
import matplotlib
matplotlib.style.use('ggplot')
print('ggplot')
# Out:
# ggplot

# %%
df = pd.DataFrame(np.random.randint(55, high = 175, size = (6, 3)), columns = ['x', 'y', 'z'])

# %%
df
# Out:
#      x    y    z
# 0  132   78   78
# 1  111  161  144
# 2  145   90  173
# 3   91   75   72
# 4   64  101   58
# 5  113   91  149

# %%
df.plot.pie (subplots = True, legend = False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd3b4576ac0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd3b458f490>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd3b459f700>],
#       dtype=object)

# %%
df.plot.pie (subplots = True, figsize = (8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd3b56638b0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd3b576e9d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd3b57c28b0>],
#       dtype=object)

# %%
df
# Out:
#      x    y    z
# 0  132   78   78
# 1  111  161  144
# 2  145   90  173
# 3   91   75   72
# 4   64  101   58
# 5  113   91  149

# %%
df.iloc[3].plot.pie()

# %%
df.iloc[2:4].plot(kind='pie', subplots=True, autopct='%1.1f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fd3b5d92b80>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd3b5f79280>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fd3b5f9a4f0>],
#       dtype=object)
